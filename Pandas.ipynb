# %% [markdown]
# ## Pandas

# %%
import pandas as pd
file1 = ('Downloads/demo1_historic.csv')

# %%
df_historic_data = pd.read_csv(file1)

# %%
type(df_historic_data)
# Out:
# pandas.core.frame.DataFrame

# %%
df_historic_data.shape
# Out:
# (1000, 10)

# %%
df_historic_data.head(15)
# Out:
#      ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 0    S1   41           1             1               3             23
# 1    S2   37           0             0               0              5
# 2    S3   49           0             0               0             44
# 3    S4   24           0             0               0             40
# 4    S5   48           1             1               3             36
# 5    S6   48           1             0               0             50
# 6    S7   20           1             0               0              4
# 7    S8   27           0             0               0              5
# 8    S9   29           0             0               0             16
# 9   S10   34           1             1               2             18
# 10  S11   49           1             1               2              3
# 11  S12   44           1             0               0              5
# ...

# %%
df_historic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
# ID                           1000 non-null object
# Age                          1000 non-null int64
# Is_Married                   1000 non-null int64
# Has_Children                 1000 non-null int64
# Children_Count               1000 non-null int64
# Home_Distance                1000 non-null int64
# Drinks_Tea                   1000 non-null int64
# Lectures_Missed              1000 non-null int64
# Average_Assignments_Score    1000 non-null int64
# Exam_Result                  1000 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 78.2+ KB

# %%
df_sliced = df_historic_data.iloc[2, :]
df_sliced
# Out:
# ID                           S3
# Age                          49
# Is_Married                    0
# Has_Children                  0
# Children_Count                0
# Home_Distance                44
# Drinks_Tea                    1
# Lectures_Missed               9
# Average_Assignments_Score    52
# Exam_Result                   1
# Name: 2, dtype: object

# %%
df_historic_data.tail(6)
# Out:
#         ID  Age  Is_Married  Has_Children  Children_Count  Home_Distance  \
# 994   S995   42           0             0               0             13
# 995   S996   32           0             0               0              2
# 996   S997   29           1             0               0             22
# 997   S998   47           1             0               0             13
# 998   S999   21           0             0               0             15
# 999  S1000   31           1             0               0             21
#
#      Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result
# 994           1                3                         64            1
# 995           1                9                         48            0
# 996           0               10                         56            0
# 997           0               10                         64            1
# 998           0                4                         75            1
# ...

# %%
type(df_sliced)
# Out:
# pandas.core.series.Series

# %%
df_historic_data.nunique()
# Out:
# ID                           1000
# Age                            31
# Is_Married                      2
# Has_Children                    2
# Children_Count                 11
# Home_Distance                  51
# Drinks_Tea                      2
# Lectures_Missed                11
# Average_Assignments_Score      97
# Exam_Result                     2
# dtype: int64

# %%
df_historic_data.describe() # Summary Statistics Table
# Out:
#                Age   Is_Married  Has_Children  Children_Count  Home_Distance  \
# count  1000.000000  1000.000000    1000.00000     1000.000000     1000.00000
# mean     34.930000     0.489000       0.26400        0.803000       25.56400
# std       8.995222     0.500129       0.44102        1.784201       14.54529
# min      20.000000     0.000000       0.00000        0.000000        0.00000
# 25%      27.000000     0.000000       0.00000        0.000000       13.00000
# 50%      35.000000     0.000000       0.00000        0.000000       26.00000
# 75%      42.000000     1.000000       1.00000        1.000000       38.00000
# max      50.000000     1.000000       1.00000       10.000000       50.00000
#
#         Drinks_Tea  Lectures_Missed  Average_Assignments_Score  Exam_Result
# count  1000.000000      1000.000000                1000.000000   1000.00000
# mean      0.496000         5.009000                  49.059000      0.61800
# ...

# %%
df_historic_data.Is_Married.value_counts()
# Out:
# 0    511
# 1    489
# Name: Is_Married, dtype: int64

# %%
# %matplotlib inline
df_historic_data.Is_Married.hist()

# %%
df_historic_data.iloc[1:4, 0:5]
# Out:
#    ID  Age  Is_Married  Has_Children  Children_Count
# 1  S2   37           0             0               0
# 2  S3   49           0             0               0
# 3  S4   24           0             0               0
